# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /root/anaconda3/lib/python3.7/site-packages (5.1.2)
# Requirement already satisfied: jupyter-client in /root/anaconda3/lib/python3.7/site-packages (from ipykernel) (5.3.3)
# Requirement already satisfied: tornado>=4.2 in /root/anaconda3/lib/python3.7/site-packages (from ipykernel) (6.0.3)
# Requirement already satisfied: ipython>=5.0.0 in /root/anaconda3/lib/python3.7/site-packages (from ipykernel) (7.8.0)
# Requirement already satisfied: traitlets>=4.1.0 in /root/anaconda3/lib/python3.7/site-packages (from ipykernel) (4.3.3)
# Requirement already satisfied: jupyter-core in /root/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.1 in /root/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel) (2.8.0)
# Requirement already satisfied: pyzmq>=13 in /root/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel) (18.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (4.7.0)
# Requirement already satisfied: jedi>=0.10 in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (0.15.1)
# Requirement already satisfied: pygments in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (2.4.2)
# Requirement already satisfied: decorator in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (4.4.0)
# Requirement already satisfied: setuptools>=18.5 in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (41.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (2.0.10)
# Requirement already satisfied: pickleshare in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (0.7.5)
# Requirement already satisfied: backcall in /root/anaconda3/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (0.1.0)
# Requirement already satisfied: ipython-genutils in /root/anaconda3/lib/python3.7/site-packages (from traitlets>=4.1.0->ipykernel) (0.2.0)
# Requirement already satisfied: six in /root/anaconda3/lib/python3.7/site-packages (from traitlets>=4.1.0->ipykernel) (1.12.0)
# Requirement already satisfied: ptyprocess>=0.5 in /root/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /root/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel) (0.5.1)
# Requirement already satisfied: wcwidth in /root/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel) (0.1.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('gruvboxd')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #ebdbb2;
#  background-color: #1d2021;
#  background: #1d2021;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d2021;
#  background: #1d2021;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #fbf1c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
#  min-height: 27px;
#  padding-top: 2px;
#  padding-bottom: 0px;
# }
# #maintoolbar .container {
#  width: 75%;
#  margin-right: auto;
#  margin-left: auto;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #fbf1c7;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
#  font-family: "FontAwesome" !important;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  font-size: 18px;
#  -moz-osx-font-smoothing: grayscale;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #ebdbb2;
#  padding: 8px 8px;
#  background: #1b1d1e;
#  background-color: #1b1d1e;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #ebdbb2;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #ebdbb2;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #282828;
#  background-color: #282828;
#  padding: 2px;
#  border-bottom: 2px solid rgba(70,70,70,.5);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #282828;
#  background-color: #282828;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# button#refresh_running_list {
#  border: none !important;
# }
# button#refresh_cluster_list {
#  border: none !important;
# }
# div.running_list_info.toolbar_info {
#  font-size: 15px;
#  padding: 4px 0 4px 0;
#  margin-top: 5px;
#  margin-bottom: 8px;
#  height: 24px;
#  line-height: 24px;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
#  border-color: transparent;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #d5c4a1;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# .fa-folder:before {
#  color: #83a598;
# }
# .fa-arrow-up:before {
#  font-size: 14px;
# }
# .fa-arrow-down:before {
#  font-size: 14px;
# }
# span#last-modified.btn.btn-xs.btn-default.sort-action:hover .fa,
# span#sort-name.btn.btn-xs.btn-default.sort-action:hover .fa {
#  color: #fe8019;
# }
# .folder_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f07b";
#  color: #83a598;
# }
# .notebook_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f02d";
#  position: relative;
#  color: #b8bb26 !important;
#  top: 0px;
# }
# .file_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f15b";
#  position: relative;
#  top: 0px;
#  color: #d5c4a1 !important;
# }
# #project_name a {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  text-align: -webkit-auto;
#  vertical-align: baseline;
#  font-size: 18px;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: sans-serif;
#  font-size: 17px;
#  color: #3c3836;
# }
# span#login_widget > .button,
# #logout {
#  font-family: "Proxima Nova", sans-serif;
#  color: #d5c4a1;
#  background: transparent;
#  background-color: transparent;
#  border: 2px solid rgba(70,70,70,.5);
#  font-weight: normal;
#  box-shadow: none;
#  text-shadow: none;
#  border-radius: 3px;
#  margin-right: 10px;
#  padding: 2px 7px;
# }
# span#login_widget > .button:hover,
# #logout:hover {
#  color: #fe8019;
#  background-color: transparent;
#  background: transparent;
#  border: 2px solid #fe8019;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 3px;
# }
# span#login_widget > .button:focus,
# #logout:focus,
# span#login_widget > .button.focus,
# #logout.focus,
# span#login_widget > .button:active,
# #logout:active,
# span#login_widget > .button.active,
# #logout.active,
# .open > .dropdown-togglespan#login_widget > .button,
# .open > .dropdown-toggle#logout {
#  color: #83a598;
#  background-color: #d5c4a1;
#  background: #d5c4a1;
#  border-color: #d5c4a1;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 2px;
# }
# body > #header #header-container {
#  padding-bottom: 0px;
#  padding-top: 4px;
#  box-sizing: border-box;
#  -moz-box-sizing: border-box;
#  -webkit-box-sizing: border-box;
# }
# body > #header {
#  background: #1d2021;
#  background-color: #1d2021;
#  position: relative;
#  z-index: 100;
# }
# .list_container {
#  font-size: 13pt;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(70,70,70,.4);
#  font-size: 13pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-top: 6px;
#  padding-bottom: 2px;
#  padding-left: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 13pt;
# }
# .item_icon {
#  color: #83a598;
#  font-size: 13pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: 1.75em;
#  width: 25%;
#  margin: 0px 0 0;
#  margin-top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 1.5em;
#  font-size: 12pt;
#  display: inline-table;
#  position: static;
# }
# #button-select-all {
#  height: 34px;
#  min-width: 55px;
#  z-index: 0;
#  border: none !important;
#  padding-top: 0px;
#  padding-bottom: 0px;
#  margin-bottom: 0px;
#  margin-top: 0px;
#  left: -3px;
#  border-radius: 0px !important;
# }
# #button-select-all:focus,
# #button-select-all:active:focus,
# #button-select-all.active:focus,
# #button-select-all.focus,
# #button-select-all:active.focus,
# #button-select-all.active.focus {
#  background-color: rgba(70,70,70,.5) !important;
#  background: rgba(70,70,70,.5) !important;
# }
# button#tree-selector-btn {
#  height: 34px;
#  font-size: 12.0pt;
#  border: none;
#  left: 0px;
#  border-radius: 0px !important;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 2px;
#  top: 4px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin-top: 1px;
#  line-height: normal;
# }
# .delete-button {
#  border: none !important;
# }
# i.fa.fa-trash {
#  font-size: 13.5pt;
# }
# .list_container a {
#  font-size: 16px;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #fbf1c7;
# }
# .list_header > div input,
# .list_item > div input {
#  margin-right: 7px;
#  margin-left: 12px;
#  vertical-align: baseline;
#  line-height: 22px;
#  position: relative;
#  top: -1px;
# }
# div.list_item:hover {
#  background-color: rgba(70,70,70,.2);
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
# }
# .breadcrumb > li + li:before {
#  content: "/\00a0";
#  padding: 0px;
#  color: #ebdbb2;
#  font-size: 18px;
# }
# #project_name > .breadcrumb {
#  padding: 0px;
#  margin-bottom: 0px;
#  background-color: transparent;
#  font-weight: normal;
#  margin-top: -2px;
# }
# ul#tabs a {
#  font-family: sans-

# %%
pip install --upgrade tensorflow
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/tensorflow/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/tensorflow/

# %%
#!pip uninstall tensorflow 
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/4c/1a/0d79814736cfecc825ab8094b39648cc9c46af7af1bae839928acb73b4dd/tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2MB)
#      |████████████▍                   | 200.7MB 195kB/s eta 0:26:54   |▎                               | 4.2MB 95kB/s eta 1:29:02     |▍                               | 6.1MB 108kB/s eta 1:18:12     |▍                               | 6.2MB 144kB/s eta 0:58:47     |▍                               | 6.6MB 37kB/s eta 3:49:16     |▌                               | 8.3MB 325kB/s eta 0:25:59     |▌                               | 8.8MB 411kB/s eta 0:20:35     |▌                               | 8.9MB 411kB/s eta 0:20:35     |▉                               | 14.1MB 55kB/s eta 2:31:29     |█▏                              | 18.6MB 143kB/s eta 0:57:45     |█▍                              | 21.7MB 93kB/s eta 1:28:23     |█▊                              | 27.1MB 410kB/s eta 0:19:52     |█▊                              | 27.3MB 360kB/s eta 0:22:38     |█▊                              | 28.0MB 189kB/s eta 0:43:01     |██                              | 32.0MB 59kB/s eta 2:15:12     |██                              | 32.7MB 256kB/s eta 0:31:24     |██▎                             | 37.5MB 67kB/s eta 1:57:44     |██▍                             | 38.5MB 852kB/s eta 0:09:21     |██▌                             | 40.0MB 133kB/s eta 0:59:28     |██▌                             | 40.8MB 46kB/s eta 2:51:38     |██▋                             | 41.7MB 298kB/s eta 0:26:29     |██▋                             | 42.7MB 239kB/s eta 0:33:01     |██▊                             | 43.0MB 212kB/s eta 0:37:12     |██▊                             | 44.1MB 120kB/s eta 1:05:34     |██▉                             | 46.1MB 29kB/s eta 4:26:19     |██▉                             | 46.5MB 10kB/s eta 12:45:17     |███                             | 48.6MB 45kB/s eta 2:52:28     |███▏                            | 51.6MB 378kB/s eta 0:20:28     |███▋                            | 58.6MB 92kB/s eta 1:22:39     |███▋                            | 58.7MB 51kB/s eta 2:28:05     |████                            | 63.0MB 405kB/s eta 0:18:39     |████                            | 64.0MB 286kB/s eta 0:26:17     |████                            | 64.6MB 47kB/s eta 2:37:11     |████                            | 64.7MB 45kB/s eta 2:45:02     |████                            | 65.1MB 98kB/s eta 1:16:04     |████                            | 66.0MB 99kB/s eta 1:15:30     |████▏                           | 68.0MB 83kB/s eta 1:29:23     |████▎                           | 69.2MB 49kB/s eta 2:30:43     |████▎                           | 69.3MB 45kB/s eta 2:45:05     |████▍                           | 70.6MB 93kB/s eta 1:19:03     |████▍                           | 70.6MB 93kB/s eta 1:19:03     |████▍                           | 71.3MB 70kB/s eta 1:44:42     |████▍                           | 71.7MB 201kB/s eta 0:36:51     |████▌                           | 71.9MB 39kB/s eta 3:06:36     |████▋                           | 74.3MB 109kB/s eta 1:07:02     |████▊                           | 75.4MB 53kB/s eta 2:16:22     |████▉                           | 78.8MB 427kB/s eta 0:17:04     |█████                           | 80.7MB 89kB/s eta 1:20:54     |█████                           | 81.6MB 250kB/s eta 0:28:59     |█████▏                          | 82.6MB 223kB/s eta 0:32:22     |█████▎                          | 84.3MB 96kB/s eta 1:14:57     |█████▎                          | 84.9MB 28kB/s eta 4:11:56     |█████▎                          | 85.5MB 35kB/s eta 3:20:18     |█████▍                          | 86.1MB 94kB/s eta 1:15:37     |█████▋                          | 91.2MB 1.6MB/s eta 0:04:27     |█████▋                          | 91.4MB 1.6MB/s eta 0:04:27     |█████▊                          | 92.1MB 314kB/s eta 0:22:28     |█████▊                          | 92.4MB 63kB/s eta 1:50:31     |██████                          | 95.4MB 58kB/s eta 1:59:21     |██████                          | 97.5MB 96kB/s eta 1:12:16     |██████                          | 97.5MB 96kB/s eta 1:12:16     |██████▏  ...
#      |████████████████████████████████| 516.2MB 1.1kB/s ta 0:00:011     |█████████████████████████▋      | 413.5MB 102kB/s eta 0:16:43     |█████████████████████████▊      | 415.0MB 163kB/s eta 0:10:20     |█████████████████████████▉      | 415.9MB 155kB/s eta 0:10:46     |█████████████████████████▉      | 416.1MB 39kB/s eta 0:42:01     |█████████████████████████▉      | 417.2MB 136kB/s eta 0:12:08     |██████████████████████████      | 418.9MB 68kB/s eta 0:23:33████████████████████████▏     | 422.0MB 15kB/s eta 1:38:46████████████████████████▎     | 423.5MB 35kB/s eta 0:44:02     |██████████████████████████▎     | 423.7MB 72kB/s eta 0:21:18��██████████████████████▍     | 425.7MB 24kB/s eta 1:02:42     |██████████████████████████▌     | 427.6MB 89kB/s eta 0:16:31     |██████████████████████████▌     | 428.2MB 40kB/s eta 0:36:20     |██████████████████████████▋     | 428.7MB 171kB/s eta 0:08:30     |███████████████████████████     | 435.1MB 147kB/s eta 0:09:11     |███████████████████████████     | 435.3MB 146kB/s eta 0:09:13     |███████████████████████████     | 435.3MB 146kB/s eta 0:09:13     |███████████████████████████     | 435.6MB 114kB/s eta 0:11:45     |███████████████████████████     | 435.8MB 95kB/s eta 0:14:05     |███████████████████████████     | 436.3MB 166kB/s eta 0:08:00     |███████████████████████████▎    | 439.7MB 54kB/s eta 0:23:33     |███████████████████████████▎    | 440.1MB 163kB/s eta 0:07:46     |███████████████████████████▍    | 441.4MB 676kB/s eta 0:01:51     |███████████████████████████▌    | 443.3MB 46kB/s eta 0:26:02     |███████████████████████████▌    | 443.5MB 135kB/s eta 0:08:55     |███████████████████████████▌    | 443.8MB 125kB/s eta 0:09:37     |███████████████████████████▌    | 444.0MB 200kB/s eta 0:06:00     |███████████████████████████▋    | 444.9MB 56kB/s eta 0:21:07     |███████████████████████████▊    | 447.1MB 50kB/s eta 0:23:01     |███████████████████████████▊    | 447.8MB 50kB/s eta 0:22:49     |███████████████████████████▊    | 448.1MB 76kB/s eta 0:14:54     |███████████████████████████▉    | 448.2MB 31kB/s eta 0:36:10     |███████████████████████████▉    | 448.4MB 26kB/s eta 0:42:06     |███████████████████████████▉    | 448.7MB 208kB/s eta 0:05:25     |████████████████████████████    | 450.3MB 63kB/s eta 0:17:18     |████████████████████████████    | 453.0MB 185kB/s eta 0:05:42     |████████████████████████████▏   | 454.8MB 42kB/s eta 0:24:11��████▍   | 457.1MB 14kB/s eta 1:06:20��████▍   | 457.4MB 12kB/s eta 1:20:55     |████████████████████████████▍   | 457.7MB 31kB/s eta 0:31:21��████▌   | 459.4MB 39kB/s eta 0:23:59     |████████████████████████████▋   | 461.9MB 185kB/s eta 0:04:53��████▊   | 463.2MB 62kB/s eta 0:14:02��████▉   | 464.2MB 14kB/s eta 0:59:38     |████████████████████████████▉   | 464.6MB 82kB/s eta 0:10:28     |████████████████████████████▉   | 464.8MB 82kB/s eta 0:10:26     |████████████████████████████▉   | 465.7MB 110kB/s eta 0:07:37     |████████████████████████████▉   | 465.8MB 110kB/s eta 0:07:36     |█████████████████████████████   | 468.1MB 103kB/s eta 0:07:47     |█████████████████████████████   | 469.4MB 74kB/s eta 0:10:31     |█████████████████████████████▏  | 470.6MB 84kB/s eta 0:09:04     |█████████████████████████████▏  | 471.2MB 61kB/s eta 0:12:15     |█████████████████████████████▎  | 472.0MB 277kB/s eta 0:02:40     |█████████████████████████████▎  | 472.1MB 57kB/s eta 0:12:45     |█████████████████████████████▋  | 477.7MB 458kB/s eta 0:01:24     |█████████████████████████████▋  | 477.8MB 458kB/s eta 0:01:24     |█████████████████████████████▊  | 479.9MB 136kB/s eta 0:04:26�███████████████  | 482.7MB 80kB/s eta 0:06:55��████████████████  | 484.4MB 57kB/s eta 0:09:19     |██████████████████████████████▎ | 489.1MB 49kB/s eta 0:09:05��██████████████████████████▎ | 489.3MB 32kB/s eta 0:13:37     |██████████████████████████████▍ | 489.7MB 83kB/s eta 0:05:18��██████████████████████████▍ | 490.2MB 82kB/s eta 0:05:18     |████████████████████████████ ...
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.18.4)
# Requirement already satisfied: grpcio>=1.8.6 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.27.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Collecting gast==0.3.3 (from tensorflow)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(104, 'ECONNRESET')"))': /simple/gast/
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(104, 'ECONNRESET')"))': /packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
#   Downloading https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Requirement already satisfied: wrapt>=1.11.1 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: absl-py>=0.7.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.9.0)
# Collecting scipy==1.4.1; python_version >= "3" (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/dd/82/c1fe128f3526b128cfd185580ba40d01371c5d299fcf7f77968e22dfcc2e/scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1MB)
#      |████████████████████████████████| 26.1MB 43kB/s eta 0:00:011    |██▉                             | 2.3MB 208kB/s eta 0:01:55     |████                            | 3.2MB 41kB/s eta 0:09:13     |██████▎                         | 5.2MB 83kB/s eta 0:04:12     |███████████▋                    | 9.5MB 53kB/s eta 0:05:09     |████████████                    | 9.7MB 277kB/s eta 0:00:59     |████████████████▎               | 13.3MB 96kB/s eta 0:02:13     |█████████████████▎              | 14.0MB 32kB/s eta 0:06:07     |███████████████████▏            | 15.6MB 35kB/s eta 0:04:59     |████████████████████▎           | 16.5MB 660kB/s eta 0:00:15     |██████████████████████▉         | 18.6MB 92kB/s eta 0:01:22     |███████████████████████▏        | 18.8MB 149kB/s eta 0:00:49     |████████████████████████▍       | 19.9MB 234kB/s eta 0:00:27     |██████████████████████████▋     | 21.7MB 112kB/s eta 0:00:39     |███████████████████████████     | 22.0MB 59kB/s eta 0:01:09     |███████████████████████████▉    | 22.6MB 322kB/s eta 0:00:11��   | 23.6MB 13kB/s eta 0:03:01��██████████▋  | 24.1MB 45kB/s eta 0:00:43��█████████████████████▎ | 24.7MB 37kB/s eta 0:00:37     |██████████████████████████████▋ | 25.0MB 119kB/s eta 0:00:10     |███████████████████████████████ | 25.2MB 35kB/s eta 0:00:25     |███████████████████████████████▏| 25.4MB 51kB/s eta 0:00:14
# Collecting h5py<2.11.0,>=2.10.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 84kB/s eta 0:00:011    |██▍                             | 215kB 70kB/s eta 0:00:38     |████▌                           | 399kB 52kB/s eta 0:00:47     |██████                          | 542kB 52kB/s eta 0:00:45
# Collecting tensorboard<2.3.0,>=2.2.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 370kB/s eta 0:00:01     |████████████████████████████▍   | 2.6MB 231kB/s eta 0:00:02
# Requirement already satisfied: termcolor>=1.1.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf>=3.8.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.11.4)
# Requirement already satisfied: google-pasta>=0.1.8 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.1.8)
# Requirement already satisfied: six>=1.12.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.12.0)
# Collecting astunparse==1.6.3 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.33.6)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/a4/f5/926ae53d6a226ec0fda5208e0e581cffed895ccc89e36ba76a8e60895b78/tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454kB)
#      |████████████████████████████████| 460kB 114kB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.3.0,>=2.2.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/51/cd/a0c1f9e4582ea64dddf76c1b808b318d01e3b858a51c715bffab1016ecc7/tensorboard_plugin_wit-1.6.0.post3-py3-none-any.whl (777kB)
#      |████████████████████████████████| 778kB 91kB/s eta 0:00:013
# Requirement already satisfied: werkzeug>=0.11.15 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.16.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.11.3)
# Requirement already satisfied: setuptools>=41.0.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (41.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2019.9.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.24.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /root/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.7)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /root/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /root/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /root/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /root/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.8)
# ERROR: turicreate 6.2.2 has requirement tensorflow<=2.0.1,>=2.0.0, but you'll have tensorflow 2.2.0 which is incompatible.
# Installing collected packages: gast, scipy, h5py, tensorboard-plugin-wit, tensorboard, astunparse, tensorflow-estimator, tensorflow
#   Found existing installation: gast 0.2.2
#     Uninstalling gast-0.2.2:
#       Successfully uninstalled gast-0.2.2
#   Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
#   Found existing installation: h5py 2.8.0
#     Uninstalling h5py-2.8.0:
#       Successfully uninstalled h5py-2.8.0
#   Found existing installation: tensorboard 2.0.2
#     Uninstalling tensorboard-2.0.2:
#       Successfully uninstalled tensorboard-2.0.2
#   Found existing installation: tensorflow-estimator 2.0.1
#     Uninstalling tensorflow-estimator-2.0.1:
#       Successfully uninstalled tensorflow-estimator-2.0.1
# Successfully installed astunparse-1.6.3 gast-0.3.3 h5py-2.10.0 scipy-1.4.1 tensorboard-2.2.2 tensorboard-plugin-wit-1.6.0.post3 tensorflow-2.2.0 tensorflow-estimator-2.2.0

# %%
import tensorflow as tf

# %%
import keras as np

# %%
import pandas as pd
import matplotlib as plt

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /root/anaconda3/lib/python3.7/site-packages (2.0.1)
# Requirement already satisfied: astor>=0.6.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.18.4)
# Requirement already satisfied: absl-py>=0.7.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio>=1.8.6 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.27.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.33.6)
# Requirement already satisfied: gast==0.2.2 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.11.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.1.8)
# Requirement already satisfied: keras-applications>=1.0.8 in /root/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: setuptools in /root/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow) (41.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (1.11.3)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.1.0,>=2.0.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 172kB/s eta 0:00:01
# Requirement already satisfied: werkzeug>=0.11.15 in /root/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.16.0)
# Requirement already satisfied: h5py in /root/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow) (2.8.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /root/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /root/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (0.2.7)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /root/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow) (2019.9.11)
# Requirement already satisfied: idna<3,>=2.5 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow) (2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /root/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /root/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /root/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (0.4.8)
# ERROR: vocabulary 1.0.4 has requirement requests==2.13.0, but you'll have requests 2.23.0 which is incompatible.
# Installing collected packages: requests
#   Found existing installation: requests 2.13.0
#     Uninstalling requests-2.13.0:
#       Successfully uninstalled requests-2.13.0
# Successfully installed requests-2.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update --all
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# Warning: >10 possible package resolutions (only showing differing packages):
#   - r/linux-64::r-abind-1.4_5-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, r/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0, r/linux-64::r-squarem-2017.10_1-r351h6115d3f_0
#   - defaults/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0, r/linux-64::r-abind-1.4_5-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, r/linux-64::r-squarem-2017.10_1-r351h6115d3f_0
#   - defaults/linux-64::r-squarem-2017.10_1-r351h6115d3f_0, r/linux-64::r-abind-1.4_5-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, r/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0
#   - defaults/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0, defaults/linux-64::r-squarem-2017.10_1-r351h6115d3f_0, r/linux-64::r-abind-1.4_5-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0
#   - defaults/linux-64::r-abind-1.4_5-r351h6115d3f_0, defaults/linux-64::r-squarem-2017.10_1-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, r/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0
#   - defaults/linux-64::r-abind-1.4_5-r351h6115d3f_0, defaults/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0, defaults/linux-64::r-squarem-2017.10_1-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0
#   - defaults/linux-64::r-abind-1.4_5-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, r/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0, r/linux-64::r-squarem-2017.10_1-r351h6115d3f_0
#   - defaults/linux-64::r-abind-1.4_5-r351h6115d3f_0, defaults/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0, r/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, r/linux-64::r-squarem-2017.10_1-r351h6115d3f_0
#   - defaults/linux-64::r-abind-1.4_5-r351h6115d3f_0, defaults/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, r/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0, r/linux-64::r-squarem-2017.10_1-r351h6115d3f_0
#   - defaults/linux-64::r-abind-1.4_5-r351h6115d3f_0, defaults/linux-64::r-deoptimr-1.0_8-r351h6115d3f_0, defaults/linux-64::r-squarem-2017.10_1-r351h6115d3f_0, r/linux-64::r-numderiv-2016.8_1-r351h6115d3f_0
#   ... and othedone
#
# ## Package Plan ##
#
#   environment location: /root/anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.02  |           py37_0           6 KB
#     _pytorch_select-0.1        |            cpu_0           3 KB
#     anaconda-custom            |           py37_1           3 KB
#     anaconda-navigator-1.9.12  |           py37_1         4.4 MB
#     anaconda-project-0.8.4     |             py_0         210 KB
#     argh-0.26.2                |           py37_0          36 KB
#     asgiref-3.2.7              |             py_0          23 KB
#     asn1crypto-1.3.0           |           py37_0         164 KB
#     astroid-2.3.3              |           py37_0         272 KB
#     astropy-4.0.1.post1        |   py37h7b6447c_1         6.1 MB
#     astunparse-1.6.3           |             py_0          17 KB
#     atomicwrites-1.4.0         |             py_0          11 KB
#     attrs-19.3.0               |             py_0          40 KB
#     autopep8-1.5.3             |             py_0          45 KB
#     babel-2.8.0                |             py_0         5.3 MB
#     backcall-0.2.0             |             py_0          15 KB
#     bcrypt-3.1.7               |   py37h7b6447c_1          41 KB
#     beautifulsoup4-4.9.1       |           py37_0         165 KB
#     bitarray-1.2.2             |   py37h7b6447c_0          83 KB
#     bleach-3.1.5               |             py_0         116 KB
#     blinker-1.4                |           py37_0          22 KB
#     bokeh-2.1.0                |           py37_0         5.4 MB
#     bottleneck-1.3.2           |   py37heb32a55_1         125 KB
#     brotlipy-0.7.0             |py37h7b6447c_1000         322 KB
#     ca-certificates-2020.1.1   |                0         125 KB
#     cachetools-4.1.0           |             py_1          15 KB
#     certifi-2020.4.5.2         |           py37_0         157 KB
#     cffi-1.14.0                |   py37h2e261b9_0         224 KB
#     click-7.1.2                |             py_0          71 KB
#     cloudpickle-1.4.1          |             py_0          30 KB
#     colorama-0.4.3             |             py_0          20 KB
#     conda-4.8.3                |           py37_0         2.8 MB
#     conda-build-3.18.11        |           py37_0         506 KB
#     conda-package-handling-1.6.1|   py37h7b6447c_0         798 KB
#     contextlib2-0.6.0.post1    |             py_0          16 KB
#     cryptography-2.9.2         |   py37h1ba5d50_0         552 KB
#     cython-0.29.20             |   py37he6710b0_0         1.9 MB
#     cytoolz-0.10.1             |   py37h7b6447c_0         376 KB
#     dask-2.18.1                |             py_0          15 KB
#     dask-core-2.18.1           |             py_0         592 KB
#     dbus-1.13.14               |       hb2f20db_0         504 KB
#     decorator-4.4.2            |             py_0          14 KB
#     diff-match-patch-20181111  |             py_0          35 KB
#     distributed-2.18.0         |           py37_0        1003 KB
#     django-3.0.3               |             py_0         2.9 MB
#     docutils-0.16              |           py37_1         660 KB
#     flake8-3.8.2               |             py_0         134 KB
#     flask-1.1.2                |             py_0          78 KB
#     fsspec-0.7.4               |             py_0          63 KB
#     future-0.18.2              |           py37_1         631 KB
#     gast-0.3.3                 |             py_0          14 KB
#     glib-2.63.1                |       h5a9c865_0         2.9 MB
#     google-auth-1.14.1         |             py_0          58 KB
#     google-auth-oauthlib-0.4.1 |             py_2          20 KB
#     google-pasta-0.2.0         |             py_0          46 KB
#     greenlet-0.4.16            |   py37h7b6447c_0          24 KB
#     h5py-2.10.0                |   py37h7918eee_0         1.0 MB
#     hypothesis-5.16.1          |             py_0         233 KB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     idna-2.9                   |             py_1          49 KB
#     imageio-2.8.0              |             py_0         3.0 MB
#     imagesize-1.2.0            |             py_0          10 KB
#     importlib-metadata-1.6.1   |           py37_0          51 KB
#     importlib_metadata-1.6.1   |                0          10 KB
#     intervaltree-3.0.2         |             py_0          25 KB
#     ipykernel-5.3.0            |   py37h5ca1d4c_0         177 KB
#     ipython-7.15.0             |           py37_0         981 KB
#     jedi-0.17.0                |           py37_0         775 KB
#     jeepney-0.4.3              |             py_0          21 KB
#     jinja2-2.11.2              |             py_0         103 KB
#     joblib-0.15.1              |             py_0         208 KB
#     json5-0.9.5                |             py_0          22 KB
#     jupyter_client-6.1.3       |             py_0          82 KB
#     jupyter_console-6.1.0      |             py_0          24 KB
#     jupyter_core-4.6.3         |           py37_0          71 KB
#     jupyterlab-2.1.4           |             py_1         3.3 MB
#     jupyterlab_server-1.1.5    |             py_0          29 KB
#     keras-2.3.1                |                0          12 KB
#     keras-base-2.3.1           |           py37_0         495 KB
#     keyring-21.1.1             |           py37_2          57 KB
#     kiwisolver-1.2.0           |   py37hfd86e86_0          84 KB
#     krb5-1.16.4                |       h173b8e3_0         1.2 MB
#     lazy-object-proxy-1.5.0    |   py37h7b6447c_0          31 KB
#     liblief-0.10.1             |       he6710b0_0         1.7 MB
#     libprotobuf-3.12.3         |       hd408876_0         2.9 MB
#     libspatialindex-1.9.3      |       he6710b0_0         2.1 MB
#     libssh2-1.9.0              |       h1ba5d50_1         269 KB
#     libtiff-4.1.0              |       h2733197_0         447 KB
#     libxml2-2.9.10             |       he19cac6_1         1.2 MB
#     libxslt-1.1.34             |       hc22bd24_0         432 KB
#     llvmlite-0.32.1            |   py37hd408876_0        14.8 MB
#     lxml-4.5.1                 |   py37hefd8a0e_0         1.2 MB
#     lzo-2.10                   |       h7b6447c_2         184 KB
#     matplotlib-3.2.1           |                0          21 KB
#     matplotlib-base-3.2.1      |   py37hef1b27d_0         5.4 MB
#     mkl_fft-1.1.0              |   py37h23d657b_0         143 KB
#     mock-4.0.2                 |             py_0          32 KB
#     more-itertools-8.4.0       |             py_0          42 KB
#     msgpack-python-1.0.0       |   py37hfd86e86_1          89 KB
#     nbformat-5.0.7             |             py_0          89 KB
#     ncurses-6.2                |       he6710b0_1         817 KB
#     networkx-2.4               |             py_0         1.1 MB
#     notebook-6.0.3             |           py37_0         4.0 MB
#     numba-0.49.1               |   py37h0573a6f_0         3.1 MB
#     numexpr-2.7.1              |   py37h423224d_0         187 KB
#     numpydoc-1.0.0             |             py_0          44 KB
#     oauthlib-3.1.0             |             py_0          91 KB
#     openpyxl-3.0.3             |             py_0         162 KB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     packaging-20.4             |             py_0          36 KB
#     pandas-1.0.4               |   py37h0573a6f_0         8.7 MB
#     parso-0.7.0                |             py_0          72 KB
#     partd-1.1.0                |             py_0          20 KB
#     patchelf-0.11              |       he6710b0_0          75 KB
#     path-13.1.0                |           py37_0          35 KB
#     path.py-12.4.0             |                0           7 KB
#     pathtools-0.1.2            |             py_1          10 KB
#     pexpect-4.8.0              |           py37_0          82 KB
#     pillow-7.1.2               |   py37hb39fc2d_0         603 KB
#     pip-20.1.1                 |           py37_1         1.7 MB
#     plotly-4.8.1               |             py_0         2.4 MB
#     pluggy-0.13.1              |           py37_0          33 KB
#     prometheus_client-0.8.0    |             py_0          47 KB
#     prompt-toolkit-3.0.5       |             py_0         245 KB
#     prompt_toolkit-3.0.5       |                0          11 KB
#     protobuf-3.12.3            |   py37he6710b0_0         645 KB
#     psutil-5.7.0               |   py37h7b6447c_0         319 KB
#     py-1.8.2                   |             py_0          72 KB
#     py-lief-0.10.1             |   py37h403a769_0         919 KB
#     pycodestyle-2.6.0          |             py_0          43 KB
#     pycosat-0.6.3              |   py37h7b6447c_0          82 KB
#     pycparser-2.20             |             py_0          92 KB
#     pycrypto-2.6.1             |  py37h7b6447c_10         375 KB
#     pydocstyle-4.0.1           |             py_0          35 KB
#     pyflakes-2.2.0             |             py_0          61 KB
#     pygments-2.6.1             |             py_0         654 KB
#     pyjwt-1.7.1                |           py37_0          33 KB
#     pylint-2.4.4               |           py37_0         420 KB
#     pyodbc-4.0.30              |   py37he6710b0_0          70 KB
#     pyopenssl-19.1.0           |           py37_0          87 KB
#     pyparsing-2.4.7            |             py_0          65 KB
#     pyrsistent-0.16.0          |   py37h7b6447c_0          94 KB
#     pyspark-2.4.5              |             py_0       198.8 MB
#     pytables-3.6.1             |   py37h71ec239_0         1.2 MB
#     pytest-5.4.3               |           py37_0         388 KB
#     pytest-astropy-0.8.0       |             py_0           9 KB
#     pytest-astropy-header-0.1.2|             py_0          12 KB
#     pytest-doctestplus-0.7.0   |             py_0          21 KB
#     pytest-openfiles-0.5.0     |             py_0          11 KB
#     python-3.7.7               |h191fe78_0_cpython        45.1 MB
#     python-dateutil-2.8.1      |             py_0         215 KB
#     python-jsonrpc-server-0.3.4|             py_0          13 KB
#     python-language-server-0.33.1|           py37_0          81 KB
#     python-libarchive-c-2.9    |             py_0          46 KB
#     pytorch-1.5.0              |cpu_py37hd91cbb3_0        26.6 MB
#     pytz-2020.1                |             py_0         184 KB
#     pywavelets-1.1.1           |   py37h7b6447c_0         3.5 MB
#     pyxdg-0.26                 |             py_0          45 KB
#     pyyaml-5.3.1               |   py37h7b6447c_0         181 KB
#     pyzmq-18.1.1               |   py37he6710b0_0         452 KB
#     qdarkstyle-2.8.1           |             py_0         176 KB
#     qtawesome-0.7.2            |             py_0         724 KB
#     qtconsole-4.7.4            |             py_0          95 KB
#     r-base-3.5.1               |       h1e0a451_2        26.5 MB
#     r-ggplot2-3.0.0            |   r351h6115d3f_0         3.3 MB
#     r-irkernel-0.8.12          |           r351_0         189 KB
#     r-knitr-1.20               |   r351h6115d3f_0         939 KB
#     r-recipes-0.1.3            |   r351h6115d3f_0         1.2 MB
#     r-reprex-0.2.0             |   r351h6115d3f_0         391 KB
#     r-rmarkdown-1.10           |   r351h6115d3f_0         2.1 MB
#     r-tidyverse-1.2.1          |   r351h6115d3f_0          90 KB
#     requests-2.23.0            |           py37_0          92 KB
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     ripgrep-11.0.2             |       he32d670_0         1.3 MB
#     rope-0.17.0                |             py_0         127 KB
#     rsa-4.0                    |             py_0          29 KB
#     rtree-0.9.4                |           py37_1          47 KB
#     ruamel_yaml-0.15.87        |   py37h7b6447c_0         256 KB
#     scikit-image-0.16.2        |   py37h0573a6f_0        23.1 MB
#     scikit-learn-0.22.1        |   py37hd81dba3_0         5.2 MB
#     scipy-1.4.1                |   py37h0b6359f_0        14.5 MB
#     seaborn-0.10.1             |             py_0         163 KB
#     secretstorage-3.1.2        |           py37_0          25 KB
#     setuptools-47.3.0          |           py37_0         522 KB
#     six-1.15.0                 |             py_0          13 KB
#     sortedcollections-1.2.1    |             py_0          13 KB
#     sortedcontainers-2.2.2     |             py_0          29 KB
#     soupsieve-2.0.1            |             py_0          33 KB
#     sphinx-3.0.4               |             py_0         1.1 MB
#     sphinxcontrib-applehelp-1.0.2|             py_0          27 KB
#     sphinxcontrib-devhelp-1.0.2|             py_0          22 KB
#     sphinxcontrib-htmlhelp-1.0.3|             py_0          27 KB
#     sphinxcontrib-qthelp-1.0.3 |             py_0          25 KB
#     sphinxcontrib-serializinghtml-1.1.4|             py_0          24 KB
#     sphinxcontrib-websupport-1.2.1|             py_0          36 KB
#     sqlalchemy-1.3.17          |   py37h7b6447c_0         1.5 MB
#     sqlite-3.31.1              |       h62c20be_1         1.1 MB
#     sqlparse-0.3.1             |             py_0          34 KB
#     statsmodels-0.11.1         |   py37h7b6447c_0         7.8 MB
#     sympy-1.6                  |           py37_0         8.6 MB
#     tbb-2020.0                 |       hfd86e86_0         1.1 MB
#     tblib-1.6.0                |             py_0          16 KB
#     tensorboard-2.2.1          |     pyh532a8cf_0         2.4 MB
#     tensorboard-plugin-wit-1.6.0|             py_0         630 KB
#     tensorflow-2.2.0           |mkl_py37h6e9ce2d_0           4 KB
#     tensorflow-base-2.2.0      |mkl_py37hd506778_0       129.6 MB
#     tensorflow-estimator-2.2.0 |     pyh208ff02_0         254 KB
#     testpath-0.4.4             |             py_0          82 KB
#     toml-0.10.0                |   py37h28b3542_0          30 KB
#     tornado-6.0.4              |   py37h7b6447c_1         611 KB
#     tqdm-4.46.0                |             py_0          60 KB
#     twisted-20.3.0             |   py37h7b6447c_0         4.0 MB
#     typing_extensions-3.7.4.1  |           py37_0          39 KB
#     ujson-1.35                 |   py37h14c3975_0          25 KB
#     urllib3-1.25.9             |             py_0         103 KB
#     watchdog-0.10.2            |           py37_0          93 KB
#     wcwidth-0.2.4              |             py_0          29 KB
#     werkzeug-1.0.1             |             py_0         240 KB
#     wheel-0.34.2               |           py37_0          51 KB
#     wrapt-1.12.1               |   py37h7b6447c_1          49 KB
#     wurlitzer-2.0.0            |           py37_0          14 KB
#     xlsxwriter-1.2.9           |             py_0         112 KB
#     xmltodict-0.12.0           |             py_0          14 KB
#     xz-5.2.5                   |       h7b6447c_0         341 KB
#     yapf-0.28.0                |             py_0         119 KB
#     zict-2.0.0                 |             py_0          13 KB
#     zipp-3.1.0                 |             py_0          13 KB
#     ------------------------------------------------------------
#                                            Total:       642.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/linux-64::_anaconda_depends-2020.02-py37_0
#   argh               pkgs/main/linux-64::argh-0.26.2-py37_0
#   asgiref            pkgs/main/noarch::asgiref-3.2.7-py_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   autopep8           pkgs/main/noarch::autopep8-1.5.3-py_0
#   blinker            pkgs/main/linux-64::blinker-1.4-py37_0
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py37h7b6447c_1000
#   cachetools         pkgs/main/noarch::cachetools-4.1.0-py_1
#   diff-match-patch   pkgs/main/noarch::diff-match-patch-20181111-py_0
#   flake8             pkgs/main/noarch::flake8-3.8.2-py_0
#   google-auth        pkgs/main/noarch::google-auth-1.14.1-py_0
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.1-py_2
#   hypothesis         pkgs/main/noarch::hypothesis-5.16.1-py_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-1.6.1-py37_0
#   intervaltree       pkgs/main/noarch::intervaltree-3.0.2-py_0
#   libspatialindex    pkgs/main/linux-64::libspatialindex-1.9.3-he6710b0_0
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.2.1-py37hef1b27d_0
#   oauthlib           pkgs/main/noarch::oauthlib-3.1.0-py_0
#   path               pkgs/main/linux-64::path-13.1.0-py37_0
#   pathtools          pkgs/main/noarch::pathtools-0.1.2-py_1
#   prompt-toolkit     pkgs/main/noarch::prompt-toolkit-3.0.5-py_0
#   pydocstyle         pkgs/main/noarch::pydocstyle-4.0.1-py_0
#   pyjwt              pkgs/main/linux-64::pyjwt-1.7.1-py37_0
#   pytest-astropy-he~ pkgs/main/noarch::pytest-astropy-header-0.1.2-py_0
#   python-jsonrpc-se~ pkgs/main/noarch::python-jsonrpc-server-0.3.4-py_0
#   python-language-s~ pkgs/main/linux-64::python-language-server-0.33.1-py37_0
#   pyxdg              pkgs/main/noarch::pyxdg-0.26-py_0
#   qdarkstyle         pkgs/main/noarch::qdarkstyle-2.8.1-py_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.0-py_0
#   rtree              pkgs/main/linux-64::rtree-0.9.4-py37_1
#   tensorboard-plugi~ pkgs/main/noarch::tensorboard-plugin-wit-1.6.0-py_0
#   toml               pkgs/main/linux-64::toml-0.10.0-py37h28b3542_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-3.7.4.1-py37_0
#   ujson              pkgs/main/linux-64::ujson-1.35-py37h14c3975_0
#   watchdog           pkgs/main/linux-64::watchdog-0.10.2-py37_0
#   xmltodict          pkgs/main/noarch::xmltodict-0.12.0-py_0
#   yapf               pkgs/main/noarch::yapf-0.28.0-py_0
#
# The following packages will be REMOVED:
#
#   astor-0.8.0-py37_0
#   backports.os-0.1.1-py37_0
#   cudatoolkit-10.0.130-0
#   cudnn-7.6.5-cuda10.0_0
#
# The following packages will be UPDATED:
#
#   anaconda-navigator                           1.9.7-py37_0 --> 1.9.12-py37_1
#   anaconda-project                               0.8.3-py_0 --> 0.8.4-py_0
#   asn1crypto                                   1.0.1-py37_0 --> 1.3.0-py37_0
#   astroid                                      2.3.1-py37_0 --> 2.3.3-py37_0
#   astropy                              3.2.2-py37h7b6447c_0 --> 4.0.1.post1-py37h7b6447c_1
#   atomicwrites       pkgs/main/linux-64::atomicwrites-1.3.~ --> pkgs/main/noarch::atomicwrites-1.4.0-py_0
#   attrs                                         19.2.0-py_0 --> 19.3.0-py_0
#   babel                                          2.7.0-py_0 --> 2.8.0-py_0
#   backcall           pkgs/main/linux-64::backcall-0.1.0-py~ --> pkgs/main/noarch::backcall-0.2.0-py_0
#   bcrypt                               3.1.7-py37h7b6447c_0 --> 3.1.7-py37h7b6447c_1
#   beautifulsoup4                               4.8.0-py37_0 --> 4.9.1-py37_0
#   bitarray                             1.0.1-py37h7b6447c_0 --> 1.2.2-py37h7b6447c_0
#   bleach             pkgs/main/linux-64::bleach-3.1.0-py37~ --> pkgs/main/noarch::bleach-3.1.5-py_0
#   bokeh                                        1.3.4-py37_0 --> 2.1.0-py37_0
#   bottleneck                           1.2.1-py37h035aef0_1 --> 1.3.2-py37heb32a55_1
#   ca-certificates                               2019.8.28-0 --> 2020.1.1-0
#   certifi                                  2019.9.11-py37_0 --> 2020.4.5.2-py37_0
#   cffi                                1.12.3-py37h2e261b9_0 --> 1.14.0-py37h2e261b9_0
#   click                pkgs/main/linux-64::click-7.0-py37_0 --> pkgs/main/noarch::click-7.1.2-py_0
#   cloudpickle                                    1.2.2-py_0 --> 1.4.1-py_0
#   colorama           pkgs/main/linux-64::colorama-0.4.1-py~ --> pkgs/main/noarch::colorama-0.4.3-py_0
#   conda                                        4.8.2-py37_0 --> 4.8.3-py37_0
#   conda-build                                 3.18.9-py37_3 --> 3.18.11-py37_0
#   conda-package-han~                   1.6.0-py37h7b6447c_0 --> 1.6.1-py37h7b6447c_0
#   contextlib2                                    0.6.0-py_0 --> 0.6.0.post1-py_0
#   cryptography                           2.7-py37h1ba5d50_0 --> 2.9.2-py37h1ba5d50_0
#   cython                             0.29.13-py37he6710b0_0 --> 0.29.20-py37he6710b0_0
#   cytoolz                             0.10.0-py37h7b6447c_0 --> 0.10.1-py37h7b6447c_0
#   dask                                           2.5.2-py_0 --> 2.18.1-py_0
#   dask-core                                      2.5.2-py_0 --> 2.18.1-py_0
#   dbus                                    1.13.6-h746ee38_0 --> 1.13.14-hb2f20db_0
#   decorator          pkgs/main/linux-64::decorator-4.4.0-p~ --> pkgs/main/noarch::decorator-4.4.2-py_0
#   distributed        pkgs/main/noarch::distributed-2.5.2-p~ --> pkgs/main/linux-64::distributed-2.18.0-py37_0
#   django             pkgs/main/linux-64::django-2.2.5-py37~ --> pkgs/main/noarch::django-3.0.3-py_0
#   docutils                                    0.15.2-py37_0 --> 0.16-py37_1
#   flask                                          1.1.1-py_0 --> 1.1.2-py_0
#   fsspec                                         0.5.2-py_0 --> 0.7.4-py_0
#   future                                      0.18.2-py37_0 --> 0.18.2-py37_1
#   gast                pkgs/main/linux-64::gast-0.2.2-py37_0 --> pkgs/main/noarch::gast-0.3.3-py_0
#   glib                                    2.56.2-hd408876_0 --> 2.63.1-h5a9c865_0
#   google-pasta                                   0.1.8-py_0 --> 0.2.0-py_0
#   greenlet                            0.4.15-py37h7b6447c_0 --> 0.4.16-py37h7b6447c_0
#   h5py                                 2.9.0-py37h7918eee_0 --> 2.10.0-py37h7918eee_0
#   icu                                       58.2-h9c2bf20_1 --> 58.2-he6710b0_3
#   idna                  pkgs/main/linux-64::idna-2.8-py37_0 --> pkgs/main/noarch::idna-2.9-py_1
#   imageio            pkgs/main/linux-64::imageio-2.6.0-py3~ --> pkgs/main/noarch::imageio-2.8.0-py_0
#   imagesize          pkgs/main/linux-64::imagesize-1.1.0-p~ --> pkgs/main/noarch::imagesize-1.2.0-py_0
#   importlib_metadata pkgs/main/linux-64::importlib_metadat~ --> pkgs/main/noarch::importlib_metadata-1.6.1-0
#   ipykernel                            5.1.2-py37h39e3cac_0 --> 5.3.0-py37h5ca1d4c_0
#   ipython                              7.8.0-py37h39e3cac_0 --> 7.15.0-py37_0
#   jedi                                        0.15.1-py37_0 --> 0.17.0-py37_0
#   jeepney                                        0.4.1-py_0 --> 0.4.3-py_0
#   jinja2                                        2.10.3-py_0 --> 2.11.2-py_0
#   joblib             pkgs/main/linux-64::joblib-0.13.2-py3~ --> pkgs/main/noarch::joblib-0.15.1-py_0
#   json5                                          0.8.5-py_0 --> 0.9.5-py_0
#   jsonschema                                   3.0.2-py37_0 --> 3.2.0-py37_0
#   jupyter_client     pkgs/main/linux-64::jupyter_client-5.~ --> pkgs/main/noarch::jupyter_client-6.1.3-py_0
#   jupyter_console    pkgs/main/linux-64::jupyter_console-6~ --> pkgs/main/noarch::jupyter_console-6.1.0-py_0
#   jupyter_core       pkgs/main/noarch::jupyter_core-4.5.0-~ --> pkgs/main/linux-64::jupyter_core-4.6.3-py37_0
#   jupyterlab                             1.1.4-pyhf63ae98_0 --> 2.1.4-py_1
#   jupyterlab_server                              1.0.6-py_0 --> 1.1.5-py_0
#   keras                                             2.2.4-0 --> 2.3.1-0
#   keras-base                                   2.2.4-py37_0 --> 2.3.1-py37_0
#   keyring                                     18.0.0-py37_0 --> 21.1.1-py37_2
#   kiwisolver                           1.1.0-py37he6710b0_0 --> 1.2.0-py37hfd86e86_0
#   krb5                                    1.16.1-h173b8e3_7 --> 1.16.4-h173b8e3_0
#   lazy-object-proxy                    1.4.2-py37h7b6447c_0 --> 1.5.0-py37h7b6447c_0
#   liblief                                  0.9.0-h7725739_2 --> 0.10.1-he6710b0_0
#   libprotobuf                             3.11.4-hd408876_0 --> 3.12.3-hd408876_0
#   libssh2                                  1.8.2-h1ba5d50_0 --> 1.9.0-h1ba5d50_1
#   libtiff                                 4.0.10-h2733197_2 --> 4.1.0-h2733197_0
#   libxml2                                  2.9.9-hea5a465_1 --> 2.9.10-he19cac6_1
#   libxslt                                 1.1.33-h7d1a2b0_0 --> 1.1.34-hc22bd24_0
#   llvmlite                            0.29.0-py37hd408876_0 --> 0.32.1-py37hd408876_0
#   lxml                                 4.4.1-py37hefd8a0e_0 --> 4.5.1-py37hefd8a0e_0
#   matplotlib                           3.1.1-py37h5429711_0 --> 3.2.1-0
#   mkl_fft                             1.0.14-py37ha843d7b_0 --> 1.1.0-py37h23d657b_0
#   mock                pkgs/main/linux-64::mock-3.0.5-py37_0 --> pkgs/main/noarch::mock-4.0.2-py_0
#   more-itertools     pkgs/main/linux-64::more-itertools-7.~ --> pkgs/main/noarch::more-itertools-8.4.0-py_0
#   msgpack-python                       0.6.1-py37hfd86e86_1 --> 1.0.0-py37hfd86e86_1
#   nbconvert                                    5.6.0-py37_1 --> 5.6.1-py37_0
#   nbformat           pkgs/main/linux-64::nbformat-4.4.0-py~ --> pkgs/main/noarch::nbformat-5.0.7-py_0
#   ncurses                                    6.1-he6710b0_1 --> 6.2-he6710b0_1
#   networkx                                         2.3-py_0 --> 2.4-py_0
#   notebook                                     6.0.1-py37_0 --> 6.0.3-py37_0
#   numba                               0.45.1-py37h962f231_0 --> 0.49.1-py37h0573a6f_0
#   numexpr                              2.7.0-py37h9e4a6bb_0 --> 2.7.1-py37h423224d_0
#   numpy                               1.17.2-py37haad9e8e_0 --> 1.18.1-py37h4f9e942_0
#   numpy-base                          1.17.2-py37hde5b4d6_0 --> 1.18.1-py37hde5b4d6_1
#   numpydoc                                       0.9.1-py_0 --> 1.0.0-py_0
#   openpyxl                                       3.0.0-py_0 --> 3.0.3-py_0
#   openssl                                 1.1.1d-h7b6447c_2 --> 1.1.1g-h7b6447c_0
#   packaging                                       19.2-py_0 --> 20.4-py_0
#   pandas                              0.25.1-py37he6710b0_0 --> 1.0.4-py37h0573a6f_0
#   parso                                          0.5.1-py_0 --> 0.7.0-py_0
#   partd                                          1.0.0-py_0 --> 1.1.0-py_0
#   patchelf                                   0.9-he6710b0_3 --> 0.11-he6710b0_0
#   path.py                                       12.0.1-py_0 --> 12.4.0-0
#   pexpect                                      4.7.0-py37_0 --> 4.8.0-py37_0
#   pillow                               6.2.0-py37h34e0f95_0 --> 7.1.2-py37hb39fc2d_0
#   pip                                         19.2.3-py37_0 --> 20.1.1-py37_1
#   plotly                                         4.5.2-py_0 --> 4.8.1-py_0
#   pluggy                                      0.13.0-py37_0 --> 0.13.1-py37_0
#   prometheus_client                              0.7.1-py_0 --> 0.8.0-py_0
#   prompt_toolkit                                2.0.10-py_0 --> 3.0.5-0
#   protobuf                            3.11.4-py37he6710b0_0 --> 3.12.3-py37he6710b0_0
#   psutil                               5.6.3-py37h7b6447c_0 --> 5.7.0-py37h7b6447c_0
#   py                    pkgs/main/linux-64::py-1.8.0-py37_0 --> pkgs/main/noarch::py-1.8.2-py_0
#   py-lief                              0.9.0-py37h7725739_2 --> 0.10.1-py37h403a769_0
#   pycodestyle        pkgs/main/linux-64::pycodestyle-2.5.0~ --> pkgs/main/noarch::pycodestyle-2.6.0-py_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py~ --> pkgs/main/noarch::pycparser-2.20-py_0
#   pycrypto                             2.6.1-py37h14c3975_9 --> 2.6.1-py37h7b6447c_10
#   pyflakes           pkgs/main/linux-64::pyflakes-2.1.1-py~ --> pkgs/main/noarch::pyflakes-2.2.0-py_0
#   pygments                                       2.4.2-py_0 --> 2.6.1-py_0
#   pylint                                       2.4.2-py37_0 --> 2.4.4-py37_0
#   pyodbc                              4.0.27-py37he6710b0_0 --> 4.0.30-py37he6710b0_0
#   pyopenssl                                   19.0.0-py37_0 --> 19.1.0-py37_0
#   pyparsing                                      2.4.2-py_0 --> 2.4.7-py_0
#   pyrsistent                          0.15.4-py37h7b6447c_0 --> 0.16.0-py37h7b6447c_0
#   pyspark                                        2.4.4-py_0 --> 2.4.5-py_0
#   pytables                             3.5.2-py37h71ec239_1 --> 3.6.1-py37h71ec239_0
#   pytest                                       5.2.1-py37_0 --> 5.4.3-py37_0
#   pytest-astropy     pkgs/main/linux-64::pytest-astropy-0.~ --> pkgs/main/noarch::pytest-astropy-0.8.0-py_0
#   pytest-doctestplus                             0.4.0-py_0 --> 0.7.0-py_0
#   pytest-openfiles                               0.4.0-py_0 --> 0.5.0-py_0
#   python                                   3.7.4-h265db76_1 --> 3.7.7-h191fe78_0_cpython
#   python-dateutil    pkgs/main/linux-64::python-dateutil-2~ --> pkgs/main/noarch::python-dateutil-2.8.1-py_0
#   python-libarchive~ pkgs/main/linux-64::python-libarchive~ --> pkgs/main/noarch::python-libarchive-c-2.9-py_0
#   pytorch                       1.3.1-cuda100py37h53c1284_0 --> 1.5.0-cpu_py37hd91cbb3_0
#   pytz                                          2019.3-py_0 --> 2020.1-py_0
#   pywavelets                           1.0.3-py37hdd07704_1 --> 1.1.1-py37h7b6447c_0
#   pyyaml                               5.1.2-py37h7b6447c_0 --> 5.3.1-py37h7b6447c_0
#   pyzmq                               18.1.0-py37he6710b0_0 --> 18.1.1-py37he6710b0_0
#   qtawesome                                      0.6.0-py_0 --> 0.7.2-py_0
#   qtconsole                                      4.5.5-py_0 --> 4.7.4-py_0
#   requests                                    2.22.0-py37_0 --> 2.23.0-py37_0
#   ripgrep                                 0.10.0-hc07d326_0 --> 11.0.2-he32d670_0
#   rope                                          0.14.0-py_0 --> 0.17.0-py_0
#   ruamel_yaml                        0.15.46-py37h14c3975_0 --> 0.15.87-py37h7b6447c_0
#   scikit-image                        0.15.0-py37he6710b0_0 --> 0.16.2-py37h0573a6f_0
#   scikit-learn                        0.21.3-py37hd81dba3_0 --> 0.22.1-py37hd81dba3_0
#   scipy                                1.3.1-py37h7c811a0_0 --> 1.4.1-py37h0b6359f_0
#   seaborn            pkgs/main/linux-64::seaborn-0.9.0-py3~ --> pkgs/main/noarch::seaborn-0.10.1-py_0
#   secretstorage                                3.1.1-py37_0 --> 3.1.2-py37_0
#   setuptools                                  41.4.0-py37_0 --> 47.3.0-py37_0
#   six                 pkgs/main/linux-64::six-1.12.0-py37_0 --> pkgs/main/noarch::six-1.15.0-py_0
#   sortedcollections  pkgs/main/linux-64::sortedcollections~ --> pkgs/main/noarch::sortedcollections-1.2.1-py_0
#   sortedcontainers   pkgs/main/linux-64::sortedcontainers-~ --> pkgs/main/noarch::sortedcontainers-2.2.2-py_0
#   soupsieve          pkgs/main/linux-64::soupsieve-1.9.3-p~ --> pkgs/main/noarch::soupsieve-2.0.1-py_0
#   sphinx                                         2.2.0-py_0 --> 3.0.4-py_0
#   sphinxcontrib-app~                             1.0.1-py_0 --> 1.0.2-py_0
#   sphinxcontrib-dev~                             1.0.1-py_0 --> 1.0.2-py_0
#   sphinxcontrib-htm~                             1.0.2-py_0 --> 1.0.3-py_0
#   sphinxcontrib-qth~                             1.0.2-py_0 --> 1.0.3-py_0
#   sphinxcontrib-ser~                             1.1.3-py_0 --> 1.1.4-py_0
#   sphinxcontrib-web~                             1.1.2-py_0 --> 1.2.1-py_0
#   sqlalchemy                           1.3.9-py37h7b6447c_0 --> 1.3.17-py37h7b6447c_0
#   sqlite                                  3.30.0-h7b6447c_0 --> 3.31.1-h62c20be_1
#   sqlparse                                       0.3.0-py_0 --> 0.3.1-py_0
#   statsmodels                         0.10.1-py37hdd07704_0 --> 0.11.1-py37h7b6447c_0
#   sympy                                          1.4-py37_0 --> 1.6-py37_0
#   tbb                                     2019.4-hfd86e86_0 --> 2020.0-hfd86e86_0
#   tblib                                          1.4.0-py_0 --> 1.6.0-py_0
#   tensorboard                           1.15.0-pyhb230dea_0 --> 2.2.1-pyh532a8cf_0
#   tensorflow                      1.15.0-mkl_py37h28c19af_0 --> 2.2.0-mkl_py37h6e9ce2d_0
#   tensorflow-base                 1.15.0-mkl_py37he1670d9_0 --> 2.2.0-mkl_py37hd506778_0
#   tensorflow-estima~                    1.15.1-pyh2649769_0 --> 2.2.0-pyh208ff02_0
#   terminado                                    0.8.2-py37_0 --> 0.8.3-py37_0
#   testpath           pkgs/main/linux-64::testpath-0.4.2-py~ --> pkgs/main/noarch::testpath-0.4.4-py_0
#   tornado                              6.0.3-py37h7b6447c_0 --> 6.0.4-py37h7b6447c_1
#   tqdm                                          4.36.1-py_0 --> 4.46.0-py_0
#   twisted                            19.10.0-py37h7b6447c_0 --> 20.3.0-py37h7b6447c_0
#   urllib3            pkgs/main/linux-64::urllib3-1.24.2-py~ --> pkgs/main/noarch::urllib3-1.25.9-py_0
#   wcwidth            pkgs/main/linux-64::wcwidth-0.1.7-py3~ --> pkgs/main/noarch::wcwidth-0.2.4-py_0
#   werkzeug                                      0.16.0-py_0 --> 1.0.1-py_0
#   wheel                                       0.33.6-py37_0 --> 0.34.2-py37_0
#   wrapt                               1.11.2-py37h7b6447c_0 --> 1.12.1-py37h7b6447c_1
#   wurlitzer                                    1.0.3-py37_0 --> 2.0.0-py37_0
#   xlsxwriter                                     1.2.1-py_0 --> 1.2.9-py_0
#   xz                                       5.2.4-h14c3975_4 --> 5.2.5-h7b6447c_0
#   zict                                           1.0.0-py_0 --> 2.0.0-py_0
#   zipp                                           0.6.0-py_0 --> 3.1.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   r-base                                                  r --> pkgs/r
#   r-ggplot2                                               r --> pkgs/r
#   r-irkernel                                              r --> pkgs/r
#   r-knitr                                                 r --> pkgs/r
#   r-recipes                                               r --> pkgs/r
#   r-reprex                                                r --> pkgs/r
#   r-rmarkdown                                             r --> pkgs/r
#   r-tidyverse                                             r --> pkgs/r
#
# The following packages will be DOWNGRADED:
#
#   _pytorch_select                                 0.2-gpu_0 --> 0.1-cpu_0
#   anaconda                                   2019.10-py37_0 --> custom-py37_1
#   lzo                                       2.10-h49e0be7_2 --> 2.10-h7b6447c_2
#   pycosat                              0.6.3-py37h14c3975_0 --> 0.6.3-py37h7b6447c_0
#
#
#
# Downloading and Extracting Packages
# lazy-object-proxy-1. | 31 KB     | ##################################### | 100%
# pyrsistent-0.16.0    | 94 KB     | ##################################### | 100%
# twisted-20.3.0       | 4.0 MB    | ##################################### | 100%
# sphinxcontrib-serial | 24 KB     | ##################################### | 100%
# cachetools-4.1.0     | 15 KB     | ##################################### | 100%
# libspatialindex-1.9. | 2.1 MB    | ##################################### | 100%
# atomicwrites-1.4.0   | 11 KB     | ##################################### | 100%
# sqlparse-0.3.1       | 34 KB     | ##################################### | 100%
# notebook-6.0.3       | 4.0 MB    | ##################################### | 100%
# pyparsing-2.4.7      | 65 KB     | ##################################### | 100%
# gast-0.3.3           | 14 KB     | ##################################### | 100%
# secretstorage-3.1.2  | 25 KB     | ##################################### | 100%
# imageio-2.8.0        | 3.0 MB    | #######################5              |  64%
# pytables-3.6.1       | 1.2 MB    |                                       |   0%
# path.py-12.4.0       | 7 KB      | ##################################### | 100%
# ripgrep-11.0.2       | 1.3 MB    | ##################################### | 100%
# distributed-2.18.0   | 1003 KB   | ###############9                      |  43%
